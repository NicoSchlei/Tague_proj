# %%
import numpy as np
import pandas as pd
#import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime
import matplotlib.ticker as ticker
import lux

# %%
chdir

# %%
test = pd.read_csv('/Google_Drive/Python/Tagueri_proj/DengAI_Predicting_Disease_Spread_-_Test_Data_Features.csv')
features = pd .read_csv('/Google_Drive/Python/Tagueri_proj/DengAI_Predicting_Disease_Spread_-_Training_Data_Features.csv')
labels = pd .read_csv('/Google_Drive/Python/Tagueri_proj/DengAI_Predicting_Disease_Spread_-_Training_Data_Labels.csv')

labels
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7677/3314172230.py in <module>
# ----> 1 test = pd.read_csv('/Google_Drive/Python/Tagueri_proj/DengAI_Predicting_Disease_Spread_-_Test_Data_Features.csv')
#       2 features = pd .read_csv('/Google_Drive/Python/Tagueri_proj/DengAI_Predicting_Disease_Spread_-_Training_Data_Features.csv')
#       3 labels = pd .read_csv('/Google_Drive/Python/Tagueri_proj/DengAI_Predicting_Disease_Spread_-_Training_Data_Labels.csv')
#       4
#       5 labels
#
# ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
labels['year_week']=labels['year'].astype(str) + ' '+labels['weekofyear'].astype(str)
labels['year_week']=pd.to_datetime(labels['year_week']+ ' 1',format=  "%Y %W %w")
labels
# Out:
#      city  year  weekofyear  total_cases  year_week
# 0      sj  1990          18            4 1990-04-30
# 1      sj  1990          19            5 1990-05-07
# 2      sj  1990          20            4 1990-05-14
# 3      sj  1990          21            3 1990-05-21
# 4      sj  1990          22            6 1990-05-28
# ...   ...   ...         ...          ...        ...
# 1451   iq  2010          21            5 2010-05-24
# 1452   iq  2010          22            8 2010-05-31
# 1453   iq  2010          23            1 2010-06-07
# 1454   iq  2010          24            1 2010-06-14
# 1455   iq  2010          25            4 2010-06-21
#
# [1456 rows x 5 columns]

# %%
#df = labels.loc[labels['city']=='sj',:]
#df

fig, ax = plt.subplots(figsize=(12, 12))

# Add x-axis and y-axis
ax.plot(labels['year_week'].loc[labels['city']=='iq'], labels['total_cases'].loc[labels['city']=='iq'])

# Set title and labels for axes


# Define the date format
#date_form = DateFormatter("%m-%d")
#ax.xaxis.set_major_formatter(date_form)

# Ensure a major tick for each week using (interval=1) 
#ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=1))

plt.show()

#plt.figure(figsize=(11,6))
#sns.lineplot(x='year_week', y='total_cases',hue='city', ci = None, data=labels, legend=False)
#plt.title(label='Dengue Fälle im Städtevergleich')
#plt.legend(title='City', loc='upper right', labels=['San Juan', 'Iquno'])
#plt.xlabel(xlabel='Jahr')
#plt.ylabel(ylabel='Dengue Fälle')
#plt.set_major_locator(mdates.WeekdayLocator(interval=1))
#plt.show()
#plt.ti

# %%
features['week_start_date']=pd.to_datetime(features['week_start_date'],format=  "%Y-%M-%d")
features
# Out:
#      city  year  weekofyear     week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      sj  1990          18 1990-01-30 00:04:00  0.122600  0.103725  0.198483
# 1      sj  1990          19 1990-01-07 00:05:00  0.169900  0.142175  0.162357
# 2      sj  1990          20 1990-01-14 00:05:00  0.032250  0.172967  0.157200
# 3      sj  1990          21 1990-01-21 00:05:00  0.128633  0.245067  0.227557
# 4      sj  1990          22 1990-01-28 00:05:00  0.196200  0.262200  0.251200
# ...   ...   ...         ...                 ...       ...       ...       ...
# 1451   iq  2010          21 2010-01-28 00:05:00  0.342750  0.318900  0.256343
# 1452   iq  2010          22 2010-01-04 00:06:00  0.160157  0.160371  0.136043
# 1453   iq  2010          23 2010-01-11 00:06:00  0.247057  0.146057  0.250357
# 1454   iq  2010          24 2010-01-18 00:06:00  0.333914  0.245771  0.278886
# 1455   iq  2010          25 2010-01-25 00:06:00  0.298186  0.232971  0.274214
#
# ...

# %%
plt.figure(figsize=(11,11))
sns.relplot(x='week_start_date',
 y='station_avg_temp_c',
 kind='line',
 hue='city',
 ci = None,
  legend=False,
   data=features,
   )

plt.title(label='Dengue Fälle')
plt.legend(title='City', loc='upper right', labels=['San Juan', 'Iquno'])
plt.xlabel(xlabel='Datum')
plt.ylabel(ylabel='Dengue Fälle')
plt.show()
