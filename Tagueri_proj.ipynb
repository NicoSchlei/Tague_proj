# %%
import numpy as np
import pandas as pd
#import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime
import matplotlib.ticker as ticker
import dataframe_image as dfi
from pandas.plotting import table
import plotly.express as px
import kaleido
import plotly.graph_objects as go

# %%
#os.chdir('path=/home/ni/Insync/n.schleinkofer@googlemail.com/Google Drive/Python/Tagueri_proj')
os.getcwd()
# Out:
# '/home/ni/Insync/n.schleinkofer@googlemail.com/Google Drive/Python/Tagueri_proj'

# %%
test = pd.read_csv('./DengAI_Predicting_Disease_Spread_-_Test_Data_Features.csv')
features = pd .read_csv('./DengAI_Predicting_Disease_Spread_-_Training_Data_Features.csv')
labels = pd .read_csv('./DengAI_Predicting_Disease_Spread_-_Training_Data_Labels.csv')
features
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1      sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2      sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3      sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4      sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
# ...   ...   ...         ...             ...       ...       ...       ...
# 1451   iq  2010          21      2010-05-28  0.342750  0.318900  0.256343
# 1452   iq  2010          22      2010-06-04  0.160157  0.160371  0.136043
# 1453   iq  2010          23      2010-06-11  0.247057  0.146057  0.250357
# 1454   iq  2010          24      2010-06-18  0.333914  0.245771  0.278886
# 1455   iq  2010          25      2010-06-25  0.298186  0.232971  0.274214
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# ...

# %%
labels['year_week']=labels['year'].astype(str) + ' ' +labels['weekofyear'].astype(str)
labels['year_week']=pd.to_datetime(labels['year_week']+ ' 1',format=  "%Y %W %w")

features['week_start_date']=features['year'].astype(str) + ' ' +features['weekofyear'].astype(str)
features['week_start_date']=pd.to_datetime(features['week_start_date']+ ' 1',format=  "%Y %W %w")
labels
features
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1      sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2      sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3      sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4      sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
# ...   ...   ...         ...             ...       ...       ...       ...
# 1451   iq  2010          21      2010-05-24  0.342750  0.318900  0.256343
# 1452   iq  2010          22      2010-05-31  0.160157  0.160371  0.136043
# 1453   iq  2010          23      2010-06-07  0.247057  0.146057  0.250357
# 1454   iq  2010          24      2010-06-14  0.333914  0.245771  0.278886
# 1455   iq  2010          25      2010-06-21  0.298186  0.232971  0.274214
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# ...

# %%
df = features
df['cases']=labels['total_cases']
df = df.round(2)
#df.iloc[0:8,0:8].to_html('table1.html')
#df.iloc[0:8,9:16].to_html('table2.html')
#df.iloc[0:8,17:25].to_html('table3.html')

#dfi.export(df.iloc[0:8,0:12],"mytable1.png")
#dfi.export(df.iloc[0:8,13:17],"mytable2.png")
#dfi.export(df.iloc[0:8,18:25],"mytable3.png")

#df.iloc[0,8]='NAN'
temp_c=df['station_avg_temp_c']
df_show=df.iloc[0:12,8:10]
df_show['station_avg_temp_c']=temp_c
dfi.export(df_show,"mytable1.png")

df = df.sort_values(by='week_start_date')

df
# Out:
# [0818/194129.234425:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0818/194129.252094:WARNING:bluez_dbus_manager.cc(247)] Floss manager not present, cannot set Floss enable/disable.
# [0818/194129.792251:INFO:headless_shell.cc(660)] Written to file /tmp/tmpxx61ibun/temp.png.
#      city  year  weekofyear week_start_date  ndvi_ne  ndvi_nw  ndvi_se  \
# 0      sj  1990          18      1990-04-30     0.12     0.10     0.20
# 1      sj  1990          19      1990-05-07     0.17     0.14     0.16
# 2      sj  1990          20      1990-05-14     0.03     0.17     0.16
# 3      sj  1990          21      1990-05-21     0.13     0.25     0.23
# 4      sj  1990          22      1990-05-28     0.20     0.26     0.25
# ...   ...   ...         ...             ...      ...      ...      ...
# 1452   iq  2010          22      2010-05-31     0.16     0.16     0.14
# 1453   iq  2010          23      2010-06-07     0.25     0.15     0.25
# ...

# %%
df
df=df.fillna(df.mean())
df.isnull().values.any()
df.isnull().sum().sum()
df['city'] = df['city'].astype(str)
#df.dtypes
df.to_csv('df.csv')
# Out:
# /tmp/ipykernel_80278/349918859.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df=df.fillna(df.mean())
# /tmp/ipykernel_80278/349918859.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df=df.fillna(df.mean())

# %%
fig = px.histogram(df, x='station_avg_temp_c',color='city',labels={
                     "station_avg_temp_c": "Temperatur [°C]",
                     'city': 'Stadt'
                     },width=800, height=600,
                      template='simple_white')

newnames = {'sj' : 'San Juan, Puerto Rico', 'iq' : 'Iquitos, Peru'}
fig.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                      legendgroup = newnames[t.name],
                                      hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])))
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.01
))


fig.write_image("./fig_histo.png")

                                      
fig.show()

# %%
fig = px.scatter(df, x='station_avg_temp_c', y='reanalysis_specific_humidity_g_per_kg',color='city',labels={
                     "station_avg_temp_c": "Temperatur [°C]",
                     'reanalysis_specific_humidity_g_per_kg':'Luftfeuchtigkeit [g/kg]',
                     'city': 'Stadt'
                     },width=800, height=600,
                      template='simple_white')

newnames = {'sj' : 'San Juan, Puerto Rico', 'iq' : 'Iquitos, Peru'}
fig.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                      legendgroup = newnames[t.name],
                                      hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])))
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.01
))


fig.write_image("./figtemp.png")


                                  
fig.show()

# %%
#df.set_index(['week_start_date'])
#print(df.loc['2000-6-1':'2000-6-10'])

fig_cases_year = px.line(df,x='week_start_date',y='cases',color='city',labels={
                     "week_start_date": "Jahr",
                     'city': 'Stadt',
                     'cases': 'Dengue Fälle'
                     },width=800, height=600,
                     template='simple_white',
                     title='Dengue Fälle im Städtevergleich'
                        )

newnames = {'sj' : 'San Juan, Puerto Rico', 'iq' : 'Iquitos, Peru', 'trace 2':'Luftfeuchtigkeit'}
fig_cases_year.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                      legendgroup = newnames[t.name],
                                      hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])))

fig_cases_year.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="right",
    x=0.99))

fig_cases_year.update_xaxes(
    dtick="M12",
    tickformat="%Y")

fig_cases_year.write_image("./figcases.png")

fig_cases_year.show()



df[(df['week_start_date'] > '2010-01-01') & (df['week_start_date'] < '2012-01-01')]
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 1431   iq  2010           1      2010-01-04  0.120000  0.180000  0.160000
# 1432   iq  2010           2      2010-01-11  0.150000  0.140000  0.140000
# 1433   iq  2010           3      2010-01-18  0.250000  0.230000  0.190000
# 1434   iq  2010           4      2010-01-25  0.260000  0.230000  0.220000
# 1435   iq  2010           5      2010-02-01  0.170000  0.140000  0.120000
# 1436   iq  2010           6      2010-02-08  0.230000  0.190000  0.160000
# 1437   iq  2010           7      2010-02-15  0.290000  0.250000  0.210000
# 1438   iq  2010           8      2010-02-22  0.300000  0.260000  0.230000
# 1439   iq  2010           9      2010-03-01  0.130000  0.180000  0.120000
# 1440   iq  2010          10      2010-03-08  0.310000  0.290000  0.270000
# 1441   iq  2010          11      2010-03-15  0.290000  0.250000  0.280000
# 1442   iq  2010          12      2010-03-22  0.270000  0.300000  0.300000
# ...

# %%
fig_cases_year_hist = px.histogram(df,x='cases',color='city')
fig_cases_year_hist.show()

# %%
#df.set_index(['week_start_date'])
#print(df.loc['2000-6-1':'2000-6-10'])

#subfig = make_subplots(specs=[[{"secondary_y": True}]])

from unicodedata import name


fig_cases_year = px.line(df[df['city']=='sj'],x='week_start_date',y='cases',color='city',labels={
                     "week_start_date": "Jahr",
                     'city': '',
                     'cases': ''
                     },width=800, height=600,
                     template='simple_white',
                     title='Dengue Fälle und Niederschlag in San Juan'
                        )

newnames = {'sj' : 'Dengue Fälle', 'iq' : 'Iquitos, Peru'}
fig_cases_year.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                      legendgroup = newnames[t.name],
                                      hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])))


#sub_fig = px.line(df,x='week_start_date', y='reanalysis_precip_amt_kg_per_m2',color = 'city')

#fig_cases_year.add_traces(sub_fig.data)  


fig_cases_year.add_trace(go.Scatter(x=df.loc[df['city']=='sj','week_start_date'], y=df.loc[df['city']=='sj','reanalysis_precip_amt_kg_per_m2'],name='Niederschlag [kg/m²]',mode='lines',opacity=0.5)) 

fig_cases_year.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="right",
    x=0.99))

fig_cases_year.update_xaxes(
    dtick="M12",
    tickformat="%Y")

fig_cases_year.write_image("./figtemp_niederschlag.png")

fig_cases_year.show()

# %%
corr = df.corr()

s = corr.unstack()
so = s.sort_values(kind="quicksort")

print(so)
# Out:
# reanalysis_tdtr_k          reanalysis_min_air_temp_k   -0.815504
# reanalysis_min_air_temp_k  reanalysis_tdtr_k           -0.815504
#                            station_diur_temp_rng_c     -0.695008
# station_diur_temp_rng_c    reanalysis_min_air_temp_k   -0.695008
# reanalysis_min_air_temp_k  reanalysis_max_air_temp_k   -0.600850
#                                                           ...
# station_avg_temp_c         station_avg_temp_c           1.000000
# station_diur_temp_rng_c    station_diur_temp_rng_c      1.000000
# station_max_temp_c         station_max_temp_c           1.000000
# reanalysis_max_air_temp_k  reanalysis_max_air_temp_k    1.000000
# cases                      cases                        1.000000
# Length: 529, dtype: float64

# %%
df_sj = df[df['city']=='sj']
labels_sk = np.array(df_sj['cases'])
date = df_sj['week_start_date']
features_sk= df_sj.drop(['cases','year','weekofyear','week_start_date','city'], axis = 1)

features_sk
# Out:
#      ndvi_ne   ndvi_nw  ndvi_se  ndvi_sw  precipitation_amt_mm  \
# 0       0.12  0.100000     0.20     0.18                 12.42
# 1       0.17  0.140000     0.16     0.16                 22.82
# 2       0.03  0.170000     0.16     0.17                 34.54
# 3       0.13  0.250000     0.23     0.24                 15.36
# 4       0.20  0.260000     0.25     0.25                  7.52
# ..       ...       ...      ...      ...                   ...
# 931     0.08 -0.040000     0.31     0.30                 27.19
# 932    -0.04 -0.020000     0.12     0.07                  3.82
# 933    -0.16 -0.050000     0.14     0.14                 16.96
# 934     0.00  0.130577     0.20     0.21                  0.00
# 935    -0.04 -0.010000     0.08     0.09                  0.00
#
#      reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                   297.57                 297.74
# 1                   298.21                 298.44
# 2                   298.78                 298.88
# ...

# %%
from random import shuffle
from sklearn.model_selection import train_test_split

train_features, test_features, train_labels, test_labels = train_test_split(features_sk, labels_sk, test_size = 0.25, random_state = 42,shuffle=False)
train_features
# Out:
#       ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  precipitation_amt_mm  \
# 0    0.120000     0.10     0.20     0.18                 12.42
# 1    0.170000     0.14     0.16     0.16                 22.82
# 2    0.030000     0.17     0.16     0.17                 34.54
# 3    0.130000     0.25     0.23     0.24                 15.36
# 4    0.200000     0.26     0.25     0.25                  7.52
# ..        ...      ...      ...      ...                   ...
# 697 -0.090000     0.10     0.25     0.21                 99.61
# 698  0.142187     0.02     0.22     0.21                 78.94
# 699  0.020000     0.03     0.16     0.11                  0.61
# 700  0.020000     0.04     0.24     0.27                118.50
# 701 -0.040000     0.06     0.17     0.13                 20.44
#
#      reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                   297.57                 297.74
# 1                   298.21                 298.44
# 2                   298.78                 298.88
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'Fälle.')
from statsmodels.tools import eval_measures
score = eval_measures.meanabs(predictions, test_labels)
score
# Out:
# Mean Absolute Error: 29.45 Fälle.
# 29.448871092796093

# %%
test_features['cases'] = test_labels
test_features['rf_predict'] = predictions
test_features['date']=date
test_features
# Out:
#       ndvi_ne   ndvi_nw  ndvi_se  ndvi_sw  precipitation_amt_mm  \
# 702  0.090000  0.000000     0.09     0.09                 96.70
# 703  0.142187  0.160000     0.14     0.12                 79.96
# 704  0.070000  0.060000     0.07     0.07                 97.28
# 705 -0.220000  0.020000     0.13     0.14                390.60
# 706 -0.070000 -0.040000     0.24     0.21                 16.20
# ..        ...       ...      ...      ...                   ...
# 931  0.080000 -0.040000     0.31     0.30                 27.19
# 932 -0.040000 -0.020000     0.12     0.07                  3.82
# 933 -0.160000 -0.050000     0.14     0.14                 16.96
# 934  0.000000  0.130577     0.20     0.21                  0.00
# 935 -0.040000 -0.010000     0.08     0.09                  0.00
#
#      reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 702                 300.95                 301.11
# 703                 300.16                 300.24
# ...

# %%
fig = px.scatter(width=800,height= 600, template='simple_white')

#fig_cases_year = px.line(test_features,x='date', y = 'cases',
#                     width=800, height=600,
#                     template='simple_white',
#                     title='Dengue Fälle und Niederschlag in San Juan'
#                        )
fig.add_trace(go.Scatter(x=test_features['date'], y=test_features['rf_predict'],name='Vorhersagen (Random Forest)',mode='lines',opacity=1)) 
fig.add_traces(go.Scatter(x=test_features['date'], y=test_features['cases'],name='Fälle',mode='lines', line=dict(color='blue')))


fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.01))

fig.update_layout(
    title="Vergleich der Vorhersagen und tatsächlichen Werte (San Juan)",
    xaxis_title="Jahr",
    yaxis_title="Dengue Fälle",
    legend_title="",
)


    

fig.update_xaxes(
    dtick="M12",
    tickformat="%Y")

fig.write_image("./figpred.png")

fig.show()

# %%
predictions
feature_list = list(train_features.columns)
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];

x_values = list(range(len(importances)))
importances = rf.feature_importances_
name = rf.feature_names_in_

d = {'value':x_values,'feature': name, 'importance':importances}
impo = pd.DataFrame(d)
impo = impo.sort_values('importance')

fig_impo = px.bar(impo, x='feature', y='importance',width=900,height= 600, template='simple_white')
fig_impo.update_layout(
    xaxis = dict(
        tickmode = 'array',
        #tickvals = x_values,
        ticktext = feature_list
    ))
fig_impo.update_layout(
    title="Feature Importance",
    xaxis_title="Feature",
    yaxis_title="Importance",
    legend_title="")

fig_impo.write_image("./figimportance.png")

fig_impo.show()
# Out:
# Variable: ndvi_nw              Importance: 0.09
# Variable: ndvi_sw              Importance: 0.09
# Variable: reanalysis_relative_humidity_percent Importance: 0.08
# Variable: station_max_temp_c   Importance: 0.08
# Variable: reanalysis_dew_point_temp_k Importance: 0.07
# Variable: reanalysis_precip_amt_kg_per_m2 Importance: 0.07
# Variable: reanalysis_specific_humidity_g_per_kg Importance: 0.07
# Variable: ndvi_se              Importance: 0.05
# Variable: reanalysis_tdtr_k    Importance: 0.05
# Variable: station_precip_mm    Importance: 0.05
# Variable: reanalysis_max_air_temp_k Importance: 0.04
# Variable: station_avg_temp_c   Importance: 0.04
# Variable: station_diur_temp_rng_c Importance: 0.04
# Variable: ndvi_ne              Importance: 0.03
# Variable: reanalysis_air_temp_k Importance: 0.03
# Variable: reanalysis_avg_temp_k Importance: 0.03
# Variable: precipitation_amt_mm Importance: 0.02
# Variable: reanalysis_min_air_temp_k Importance: 0.02
# ...

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin'
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tree = rf.estimators_[5]
# Export the image to a dot file
export_graphviz(tree, out_file = 'tree.dot', feature_names = feature_list, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree.dot')
# Write graph to a png file
graph.write_png('tree_full.png')

# %%
# Limit depth of tree to 3 levels
rf_small = RandomForestRegressor(n_estimators=10, max_depth = 2)
rf_small.fit(train_features, train_labels)
# Extract the small tree
tree_small = rf_small.estimators_[5]
# Save the tree as a png image
export_graphviz(tree_small, out_file = 'small_tree.dot', feature_names = feature_list, rounded = True, precision = 1)
(graph, ) = pydot.graph_from_dot_file('small_tree.dot')
graph.write_png('small_tree.png');
#graph.set_size('"5,5!"')
#
#graph.write_png('small_tree_resize.png');
